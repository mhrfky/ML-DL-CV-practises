# %%
import cv2
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/content/drive/MyDrive/cv_resources/coins.jpg')
blur = cv.blur(img,(5,5))
median = cv.medianBlur(img,5)
gaus = cv.GaussianBlur(img,(5,5),0)
bilateral = cv.bilateralFilter(img,9,75,75)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-d234e3e7b964> in <module>()
#       1
#       2 img = cv.imread('/content/drive/MyDrive/cv_resources/coins.jpg')
# ----> 3 blur = cv.blur(img,(5,5))
#       4 median = cv.medianBlur(img,5)
#       5 gaus = cv.GaussianBlur(img,(5,5),0)
#
# error: OpenCV(4.1.2) /io/opencv/modules/core/src/matrix.cpp:757: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'locateROI'

# %%
plt.subplot(231),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(232),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(233),plt.imshow(median),plt.title('median')
plt.xticks([]), plt.yticks([])
plt.subplot(234),plt.imshow(gaus),plt.title('Gaussian blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(235),plt.imshow(bilateral),plt.title('bilateral filtering')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1cf87ceeb39a> in <module>()
# ----> 1 plt.subplot(231),plt.imshow(img),plt.title('Original')
#       2 plt.xticks([]), plt.yticks([])
#       3 plt.subplot(232),plt.imshow(blur),plt.title('Blurred')
#       4 plt.xticks([]), plt.yticks([])
#       5 plt.subplot(233),plt.imshow(median),plt.title('median')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ...

# %%
img = cv.imread('/content/drive/MyDrive/cv_resources/img2.jpg')
blur = cv.blur(img,(5,5))
median = cv.medianBlur(img,5)
gaus = cv.GaussianBlur(img,(5,5),0)
bilateral = cv.bilateralFilter(img,9,75,75)

# %%
plt.subplot(231),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(232),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(233),plt.imshow(median),plt.title('median')
plt.xticks([]), plt.yticks([])
plt.subplot(234),plt.imshow(gaus),plt.title('Gaussian blurred')
plt.xticks([]), plt.yticks([])
plt.subplot(235),plt.imshow(bilateral),plt.title('bilateral filtering')
plt.xticks([]), plt.yticks([])
plt.show()
